# %% [markdown]
# ## Probelm 12 - Highly Divisible Triangular Number
#
# > The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
# >
# > `1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...`
# >
# > Let us list the factors of the first seven triangle numbers:
# >
# >     1: 1
# >     3: 1,3
# >     6: 1,2,3,6
# >     10: 1,2,5,10
# >     15: 1,3,5,15
# >     21: 1,3,7,21
# >     28: 1,2,4,7,14,28
# >
# > We can see that 28 is the first triangle number to have over five divisors.
# >
# > What is the value of the first triangle number to have over five hundred divisors?

# %% [markdown]
# ### Brute Force

# %%
def divTriangle(n):
    """return first number with n divisibles"""
    nat = [1]
    next = 2
    j = 0
    while j < n:
        nat.append(nat[-1] + next)
        next += 1
        i = 1
        j = 0
        while i <= nat[-1]:
            if nat[-1] % i == 0:
                j += 1
            i += 1
    return nat[-1]

print(divTriangle(100))

# %% [markdown]
# ### Number Theory

# %%
from math import sqrt

def divisors(n):
    l = list()
    for i in range(1, int(sqrt(n))):
        if n % i == 0:
            l.append(i)
            l.append(n // i)
    return l

x = 500
i = 2
n = 1
while True:
    if len(divisors(n)) > x:
        print(n)
        break
    n = i + n
    i += 1
# Out:
# 76576500
